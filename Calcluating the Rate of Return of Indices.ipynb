# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.tail()
# Out:
#                   ^GSPC
# Date
# 2020-10-06  3360.969971
# 2020-10-07  3419.439941
# 2020-10-08  3446.830078
# 2020-10-09  3477.139893
# 2020-10-12  3541.800049

# %%
ind_data.head()
# Out:
#                  ^GSPC
# Date
# 1997-01-02  737.010010
# 1997-01-03  748.030029
# 1997-01-06  747.650024
# 1997-01-07  753.229980
# 1997-01-08  748.409973

# %%
(ind_data/ind_data.iloc[0]* 100).plot(figsize=(16,6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC
# Date
# 2020-10-06 -0.013974
# 2020-10-07  0.017397
# 2020-10-08  0.008010
# 2020-10-09  0.008794
# 2020-10-12  0.018596

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC    0.085078
# dtype: float64

# %%
tickers = ['PG']

data_2 = pd.DataFrame()
 
for t in tickers:
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG
# Date
# 2020-10-06  139.610001
# 2020-10-07  140.699997
# 2020-10-08  141.649994
# 2020-10-09  142.919998
# 2020-10-12  144.690002

# %%
(data_2 / data_2.iloc[0] * 100.plot(figsize=(15,5));
plt.show()
# Out:
#   File "<ipython-input-38-70dfc25080d7>", line 1
#     (data_2 / data_2.iloc[0] * 100.plot(figsize=(15,5));
#                                    ^
# SyntaxError: invalid syntax
